# %% [markdown]
# # Nearest Open Pubs in UK

# %%
import os
import numpy as np
import pandas as pd
import plotly.express as px

# %%
os.chdir(r"D:\Ritwik's Download\Innomatics Research Lab")

# %%
df = pd.read_csv("open_pubs.csv", header=None)
df
# Out:
#             0                                         1  \
# 0          22                                Anchor Inn
# 1          36                        Ark Bar Restaurant
# 2          74                                 Black Boy
# 3          75                               Black Horse
# 4          76                                Black Lion
# ...       ...                                       ...
# 51326  597119  Wrexham & District War Memorial Club Ltd
# 51327  597127                 Wrexham Lager Social Club
# 51328  597130         Wrexham Rail Sports & Social Club
# 51329  597131                        Wrexham Rugby Club
# 51330  597137                                     Y Tai
#
#                                                        2         3       4  \
# 0            Upper Street, Stratford St Mary, COLCHESTER   CO7 6LW  604749
# 1      Ark Bar And Restaurant, Cattawade Street, Bran...  CO11 1RH  610194
# 2      The Lady Elizabeth, 7 Market Hill, SUDBURY, Su...  CO10 2EA  587334
# 3            Lower Street, Stratford St Mary, COLCHESTER   CO7 6JS  622675
# 4                          Lion Road, Glemsford, SUDBURY  CO10 7RF  622675
# ...                                                  ...       ...     ...
# 51326  Wrexham War Memorial Club Farndon Street, Wrex...  LL13 8DE  333909
# 51327                 1 - 3 Union Road, Wrexham, Wrexham  LL13 7SR  333028
# 51328  Sports And Social Club, 44 Brook Street, Wrexh...  LL13 7LU  333259
# 51329  Wrexham Rugby Club Bryn Estyn Road, Wrexham, W...  LL13 9TY  335808
# 51330       Y Tai Railway Road, Brymbo, Wrexham, Wrexham  LL11 5EA  329721
#
#              5          6          7        8
# 0       234404  51.970379   0.979340  Babergh
# 1       233329  51.958698   1.057832  Babergh
# 2       241316  52.038595   0.729915  Babergh
# 3     -5527598         \N         \N  Babergh
# 4     -5527598         \N         \N  Babergh
# ...        ...        ...        ...      ...
# 51326   350438  53.047100  -2.987319  Wrexham
# 51327   350563  53.048123  -3.000485  Wrexham
# 51328   350213  53.044998  -2.996966  Wrexham
# 51329   351078  53.053094  -2.959124  Wrexham
# 51330   353785  53.076638  -3.050512  Wrexham
#
# [51331 rows x 9 columns]

# %%
df.columns = ['fsa_id','name','address','postcode','easting','northing','latitude','longitude','local_authority']
df
# Out:
#        fsa_id                                      name  \
# 0          22                                Anchor Inn
# 1          36                        Ark Bar Restaurant
# 2          74                                 Black Boy
# 3          75                               Black Horse
# 4          76                                Black Lion
# ...       ...                                       ...
# 51326  597119  Wrexham & District War Memorial Club Ltd
# 51327  597127                 Wrexham Lager Social Club
# 51328  597130         Wrexham Rail Sports & Social Club
# 51329  597131                        Wrexham Rugby Club
# 51330  597137                                     Y Tai
#
#                                                  address  postcode  easting  \
# 0            Upper Street, Stratford St Mary, COLCHESTER   CO7 6LW   604749
# 1      Ark Bar And Restaurant, Cattawade Street, Bran...  CO11 1RH   610194
# 2      The Lady Elizabeth, 7 Market Hill, SUDBURY, Su...  CO10 2EA   587334
# 3            Lower Street, Stratford St Mary, COLCHESTER   CO7 6JS   622675
# 4                          Lion Road, Glemsford, SUDBURY  CO10 7RF   622675
# ...                                                  ...       ...      ...
# 51326  Wrexham War Memorial Club Farndon Street, Wrex...  LL13 8DE   333909
# 51327                 1 - 3 Union Road, Wrexham, Wrexham  LL13 7SR   333028
# 51328  Sports And Social Club, 44 Brook Street, Wrexh...  LL13 7LU   333259
# 51329  Wrexham Rugby Club Bryn Estyn Road, Wrexham, W...  LL13 9TY   335808
# 51330       Y Tai Railway Road, Brymbo, Wrexham, Wrexham  LL11 5EA   329721
#
#        northing   latitude  longitude local_authority
# 0        234404  51.970379   0.979340         Babergh
# 1        233329  51.958698   1.057832         Babergh
# 2        241316  52.038595   0.729915         Babergh
# 3      -5527598         \N         \N         Babergh
# 4      -5527598         \N         \N         Babergh
# ...         ...        ...        ...             ...
# 51326    350438  53.047100  -2.987319         Wrexham
# 51327    350563  53.048123  -3.000485         Wrexham
# 51328    350213  53.044998  -2.996966         Wrexham
# 51329    351078  53.053094  -2.959124         Wrexham
# 51330    353785  53.076638  -3.050512         Wrexham
#
# [51331 rows x 9 columns]

# %%
df.name.unique().shape
# Out:
# (36335,)

# %%
len(df.postcode.unique())
# Out:
# 45886

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51331 entries, 0 to 51330
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   fsa_id           51331 non-null  int64
#  1   name             51331 non-null  object
#  2   address          51331 non-null  object
#  3   postcode         51331 non-null  object
#  4   easting          51331 non-null  int64
#  5   northing         51331 non-null  int64
#  6   latitude         51331 non-null  object
#  7   longitude        51331 non-null  object
#  8   local_authority  51331 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 3.5+ MB

# %% [markdown]
# ### We can see there are some missing values in columns which are represented by $\N$ so we need to replace the missing value to Null

# %% [markdown]
# **Replace The Missing Value**

# %%
def clean_missing(x):
    if x == r'\N':
        return None
    else:
        return x

# %%
df.columns
# Out:
# Index(['fsa_id', 'name', 'address', 'postcode', 'easting', 'northing',
#        'latitude', 'longitude', 'local_authority'],
#       dtype='object')

# %%
df.fsa_id = df.fsa_id.apply(clean_missing)
df.name = df.name.apply(clean_missing)
df.address = df.address.apply(clean_missing)
df.postcode = df.postcode.apply(clean_missing)
df.easting = df.easting.apply(clean_missing)
df.northing = df.northing.apply(clean_missing)
df.latitude = df.latitude.apply(clean_missing)
df.longitude = df.longitude.apply(clean_missing)
df.local_authority = df.local_authority.apply(clean_missing)

# %%
df.isnull().sum()
# Out:
# fsa_id               0
# name                 0
# address              0
# postcode             0
# easting              0
# northing             0
# latitude           767
# longitude          767
# local_authority      0
# dtype: int64

# %%
df.dropna(axis=0, inplace=True)

# %%
df.shape
# Out:
# (50564, 9)

# %%
df.isnull().sum()
# Out:
# fsa_id             0
# name               0
# address            0
# postcode           0
# easting            0
# northing           0
# latitude           0
# longitude          0
# local_authority    0
# dtype: int64

# %%
df.dtypes
# Out:
# fsa_id              int64
# name               object
# address            object
# postcode           object
# easting             int64
# northing            int64
# latitude           object
# longitude          object
# local_authority    object
# dtype: object

# %%
df.latitude = df.latitude.astype("float")
df.longitude = df.longitude.astype("float")

# %%
df
# Out:
#        fsa_id                                      name  \
# 0          22                                Anchor Inn
# 1          36                        Ark Bar Restaurant
# 2          74                                 Black Boy
# 5          97                              Brewers Arms
# 6         102                              Bristol Arms
# ...       ...                                       ...
# 51326  597119  Wrexham & District War Memorial Club Ltd
# 51327  597127                 Wrexham Lager Social Club
# 51328  597130         Wrexham Rail Sports & Social Club
# 51329  597131                        Wrexham Rugby Club
# 51330  597137                                     Y Tai
#
#                                                  address  postcode  easting  \
# 0            Upper Street, Stratford St Mary, COLCHESTER   CO7 6LW   604749
# 1      Ark Bar And Restaurant, Cattawade Street, Bran...  CO11 1RH   610194
# 2      The Lady Elizabeth, 7 Market Hill, SUDBURY, Su...  CO10 2EA   587334
# 5      The Brewers Arms, Bower House Tye, Polstead, C...   CO6 5BZ   598743
# 6                         Bristol Hill, Shotley, IPSWICH   IP9 1PU   624624
# ...                                                  ...       ...      ...
# 51326  Wrexham War Memorial Club Farndon Street, Wrex...  LL13 8DE   333909
# 51327                 1 - 3 Union Road, Wrexham, Wrexham  LL13 7SR   333028
# 51328  Sports And Social Club, 44 Brook Street, Wrexh...  LL13 7LU   333259
# 51329  Wrexham Rugby Club Bryn Estyn Road, Wrexham, W...  LL13 9TY   335808
# 51330       Y Tai Railway Road, Brymbo, Wrexham, Wrexham  LL11 5EA   329721
#
#        northing   latitude  longitude local_authority
# 0        234404  51.970379   0.979340         Babergh
# 1        233329  51.958698   1.057832         Babergh
# 2        241316  52.038595   0.729915         Babergh
# 5        240655  52.028694   0.895650         Babergh
# 6        233550  51.955042   1.267642         Babergh
# ...         ...        ...        ...             ...
# 51326    350438  53.047100  -2.987319         Wrexham
# 51327    350563  53.048123  -3.000485         Wrexham
# 51328    350213  53.044998  -2.996966         Wrexham
# 51329    351078  53.053094  -2.959124         Wrexham
# 51330    353785  53.076638  -3.050512         Wrexham
#
# [50564 rows x 9 columns]

# %%
df.name.value_counts()[:50]
# Out:
# The Red Lion                 193
# The Royal Oak                170
# Red Lion                     130
# The Crown Inn                112
# Royal Oak                    102
# The Crown                    101
# The White Hart               101
# The New Inn                   93
# The Plough Inn                92
# The Wheatsheaf                89
# The Plough                    84
# Kings Arms                    83
# The White Horse               82
# The Ship Inn                  81
# Royal British Legion          80
# New Inn                       80
# Crown Inn                     76
# The Swan                      76
# The Bell Inn                  73
# The Kings Head                71
# The Queens Head               68
# The Kings Arms                67
# The Royal British Legion      62
# Queens Head                   58
# The Bell                      58
# Railway Inn                   56
# The Swan Inn                  56
# Ship Inn                      55
# Kings Head                    55
# White Hart                    54
# The White Swan                54
# The Rising Sun                53
# The George                    53
# The Black Horse               52
# The Sun Inn                   51
# Rose And Crown                49
# The Star Inn                  47
# The Chequers                  46
# The Greyhound                 45
# Royal British Legion Club     45
# The George Inn                44
# The Fox Inn                   44
# The Golden Lion               43
# White Horse Inn               43
# The Bulls Head                42
# The Anchor Inn                42
# Rose & Crown                  41
# The Cock Inn                  41
# Prince Of Wales               40
# Masons Arms                   40
# Name: name, dtype: int64

# %%
loc = df.local_authority.value_counts()[:15]
loc
# Out:
# County Durham               680
# Leeds                       611
# Cornwall                    557
# Wiltshire                   544
# Kirklees                    524
# City of Edinburgh           506
# Birmingham                  494
# Buckinghamshire             485
# Bradford                    478
# Northumberland              446
# East Riding of Yorkshire    432
# Shropshire                  415
# Bristol, City of            408
# Dorset                      405
# Fife                        404
# Name: local_authority, dtype: int64

# %%
fig = px.bar(df, x = loc.index, y=loc.values, color = loc.index)
fig.update_layout(
    title = "<b> Numbers of Pubs in Locality Wise (TOP 10) </b>",
    xaxis_title = "Name Local Authorities",
    yaxis_title = "Count of Pubs",
    legend_title = "Local_Authority",
    paper_bgcolor = "lightgreen",
    plot_bgcolor = "cyan"
    
)
fig.show()
# Out:
# <div>                            <div id="7e4086a9-3401-4cc0-8f06-ad4ad04a0427" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e4086a9-3401-4cc0-8f06-ad4ad04a0427")) {                    Plotly.newPlot(                        "7e4086a9-3401-4cc0-8f06-ad4ad04a0427",                        [{"alignmentgroup":"True","hovertemplate":"color=County Durham<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"County Durham","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"County Durham","offsetgroup":"County Durham","orientation":"v","showlegend":true,"textposition":"auto","x":["County Durham"],"xaxis":"x","y":[680],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Leeds<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Leeds","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Leeds","offsetgroup":"Leeds","orientation":"v","showlegend":true,"textposition":"auto","x":["Leeds"],"xaxis":"x","y":[611],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Cornwall<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Cornwall","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Cornwall","offsetgroup":"Cornwall","orientation":"v","showlegend":true,"textposition":"auto","x":["Cornwall"],"xaxis":"x","y":[557],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Wiltshire<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Wiltshire","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Wiltshire","offsetgroup":"Wiltshire","orientation":"v","showlegend":true,"textposition":"auto","x":["Wiltshire"],"xaxis":"x","y":[544],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Kirklees<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Kirklees","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Kirklees","offsetgroup":"Kirklees","orientation":"v","showlegend":true,"textposition":"auto","x":["Kirklees"],"xaxis":"x","y":[524],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=City of Edinburgh<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"City of Edinburgh","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"City of Edinburgh","offsetgroup":"City of Edinburgh","orientation":"v","showlegend":true,"textposition":"auto","x":["City of Edinburgh"],"xaxis":"x","y":[506],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Birmingham<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Birmingham","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Birmingham","offsetgroup":"Birmingham","orientation":"v","showlegend":true,"textposition":"auto","x":["Birmingham"],"xaxis":"x","y":[494],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Buckinghamshire<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Buckinghamshire","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Buckinghamshire","offsetgroup":"Buckinghamshire","orientation":"v","showlegend":true,"textposition":"auto","x":["Buckinghamshire"],"xaxis":"x","y":[485],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Bradford<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Bradford","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Bradford","offsetgroup":"Bradford","orientation":"v","showlegend":true,"textposition":"auto","x":["Bradford"],"xaxis":"x","y":[478],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Northumberland<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Northumberland","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Northumberland","offsetgroup":"Northumberland","orientation":"v","showlegend":true,"textposition":"auto","x":["Northumberland"],"xaxis":"x","y":[446], ...

# %%
nam = df.name.value_counts()[:10]
nam
# Out:
# The Red Lion      193
# The Royal Oak     170
# Red Lion          130
# The Crown Inn     112
# Royal Oak         102
# The Crown         101
# The White Hart    101
# The New Inn        93
# The Plough Inn     92
# The Wheatsheaf     89
# Name: name, dtype: int64

# %%
import folium

# %%
mymap = folium.Map(location=[23.2164, 88.3529], zoom_start=12)


folium.Marker(location=[23.2164, 88.3529], icon=folium.Icon(icon='beer', prefix='fa', color='green'), popup='Your Location').add_to(mymap)

mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_0e28bed0bf90458a8daece5e5e2a198f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_0e28bed0bf90458a8daece5e5e2a198f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_0e28bed0bf90458a8daece5e5e2a198f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_0e28bed0bf90458a8daece5e5e2a198f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B23.2164%2C%2088.3529%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ### User input section to find the TOP5 Pubs

# %%
df.latitude.max()
# Out:
# 60.764969

# %%
df.latitude.min()
# Out:
# 49.892485

# %%
df.longitude.min()
# Out:
# -7.384525

# %%
df.longitude.max()
# Out:
# 1.757763

# %%
lat = float(input())
long = float(input())
ans = np.array((lat,long))
ans
# Out:
# 59.6589
# -5.63978
# array([59.6589 , -5.63978])

# %%
arr = np.transpose(np.array([df.latitude, df.longitude]))
ans - arr[0]
# Out:
# array([ 7.688521, -6.61912 ])

# %% [markdown]
# **Finding The Distance**

# %%
dis = np.sqrt(np.sum((arr-ans)**2, axis=1))
dis = dis.tolist()

# %%
newdis = [round(i, 4) for i in dis]
newdis
# Out:
# [10.1453,
#  10.2054,
#  9.9319,
#  10.0465,
#  10.3471,
#  9.9342,
#  10.1712,
#  9.8939,
#  10.0735,
#  10.0735,
#  10.0137,
#  9.8468,
#  9.9312,
#  10.167,
#  10.0355,
#  10.1255,
#  9.9944,
#  9.9507,
#  9.8987,
#  9.9433,
#  9.9296,
#  10.2106,
#  10.2609,
#  10.1918,
#  10.324,
#  9.9324,
#  9.9012,
#  9.9329,
#  10.0232,
#  10.0763,
#  9.8496,
#  9.9273,
#  10.1621,
#  9.9325,
#  9.9564,
#  10.2182,
#  9.8563,
#  10.2803,
#  9.9211,
#  10.0748,
#  10.067,
#  9.9549,
#  9.9335,
#  9.9288,
#  10.207,
#  9.9985,
#  9.9481,
#  10.2355,
#  10.0736,
#  9.8947,
#  10.1901,
#  9.9208,
#  9.8904,
#  10.2806,
#  9.9325,
#  9.8916,
#  10.0716,
#  10.2421,
#  10.0086,
#  10.1648,
#  9.994,
#  10.1427,
#  10.0908,
#  9.8952,
#  10.0737,
#  9.9707,
#  9.9449,
#  9.8935,
#  10.2505,
#  9.8409,
#  10.2081,
#  10.0124,
#  10.1802,
#  9.9295,
#  10.2099,
#  10.0289,
#  9.9312,
#  10.1714,
#  10.1087,
#  10.1453,
#  10.1283,
#  10.1288,
#  10.1297,
#  10.1283,
#  10.1299,
#  10.1746,
#  10.0973,
#  10.0601,
#  10.0534,
#  10.1619,
#  10.1313,
#  10.1266,
#  10.0609,
#  10.1391,
#  10.1682,
#  10.1309,
#  10.1205,
#  10.1266,
#  10.1553,
#  10.1271,
#  10.0928,
#  10.1204,
#  10.06,
#  10.1343,
#  10.1343,
#  10.1578,
#  10.1428,
#  10.055,
#  10.1306,
#  10.0496,
#  10.0605,
#  10.1373,
#  10.1281,
#  10.0862,
#  10.1215,
#  10.1294,
#  10.1381,
#  10.1349,
#  10.1297,
#  10.1281,
#  10.0611,
#  10.0641,
#  10.1342,
#  10.1139,
#  10.1317,
#  10.041,
#  10.0676,
#  10.0619,
#  10.1407,
#  10.0611,
#  10.1343,
#  10.0726,
#  10.129,
#  10.0494,
#  10.1012,
#  10.1228,
#  10.1035,
#  10.1176,
#  10.1204,
#  10.0601,
#  10.1333,
#  10.1444,
#  10.1394,
#  10.1204,
#  10.1575,
#  10.1516,
#  10.1349,
#  10.1338,
#  10.1523,
#  10.11,
#  9.1275,
#  9.1184,
#  9.1297,
#  9.1296,
#  9.1276,
#  9.1255,
#  9.1297,
#  9.0952,
#  8.9882,
#  9.1245,
#  9.13,
#  9.1326,
#  9.13,
#  9.1663,
#  9.0846,
#  8.9938,
#  9.1279,
#  9.1103,
#  9.1179,
#  9.1248,
#  9.1241,
#  9.1155,
#  8.9963,
#  9.0758,
#  9.1298,
#  9.1387,
#  9.1232,
#  9.1232,
#  9.1292,
#  9.1854,
#  9.128,
#  9.0278,
#  9.1369,
#  9.0085,
#  8.9669,
#  9.1364,
#  9.1299,
#  9.1264,
#  9.1244,
#  9.1195,
#  9.117,
#  9.1284,
#  9.1244,
#  9.1266,
#  9.1192,
#  9.126,
#  9.175,
#  9.1325,
#  9.1416,
#  9.1397,
#  9.1468,
#  9.026,
#  9.1287,
#  9.1208,
#  9.0667,
#  9.1289,
#  9.0409,
#  9.1267,
#  8.9459,
#  8.9437,
#  9.1348,
#  9.1232,
#  9.1214,
#  9.0533,
#  9.1817,
#  9.132,
#  9.1337,
#  9.1308,
#  9.1284,
#  9.1298,
#  9.1167,
#  9.0141,
#  9.1573,
#  9.0888,
#  9.013,
#  9.1304,
#  9.1218,
#  9.1468,
#  9.1517,
#  9.1857,
#  9.1228,
#  9.1281,
#  9.0656,
#  9.1263,
#  9.1263,
#  9.1031,
#  9.1909,
#  9.0001,
#  9.1279,
#  9.1509,
#  9.1189,
#  9.1316,
#  9.0541,
#  9.128,
#  9.1297,
#  9.1108,
#  9.1817,
#  9.1722,
#  9.1313,
#  9.0443,
#  9.1249,
#  9.1301,
#  9.1217,
#  9.0851,
#  9.0851,
#  9.1298,
#  9.1365,
#  8.9925,
#  8.9424,
#  9.1405,
#  8.9939,
#  9.1268,
#  9.0829,
#  9.1197,
#  9.1309,
#  9.0531,
#  9.0069,
#  9.1221,
#  9.1304,
#  9.0971,
#  9.1248,
#  9.0226,
#  8.9943,
#  9.0185,
#  9.1162,
#  9.1273,
#  9.14,
#  9.1843,
#  9.1316,
#  9.105,
#  9.1298,
#  9.1242,
#  9.136,
#  9.1231,
#  9.018,
#  9.1285,
#  9.9176,
#  9.7237,
#  9.7755,
#  9.9662,
#  9.9414,
#  9.9266,
#  9.9265,
#  9.9902,
#  9.9435,
#  9.9406,
#  9.9315,
#  9.9665,
#  9.9587,
#  9.9448,
#  9.98,
#  9.8874,
#  10.0334,
#  10.0403,
#  10.0252,
#  9.9868,
#  9.9987,
#  9.9478,
#  9.9433,
#  10.0122,
#  10.0662,
#  10.0489,
#  9.9926,
#  9.9977,
#  10.0706,
#  9.7501,
#  9.9194,
#  9.9454,
#  9.9473,
#  9.9483,
#  10.0683,
#  9.7348,
#  9.721,
#  9.9921,
#  10.069,
#  10.0691,
#  9.9453,
#  10.0486,
#  10.1249,
#  9.9329,
#  10.0603,
#  9.8856,
#  10.0094,
#  10.0117,
#  10.0562,
#  9.8053,
#  9.7472,
#  10.0625,
#  10.0494,
#  10.0074,
#  10.0697,
#  10.0597,
#  9.817,
#  9.9076,
#  9.8863,
#  10.0689,
#  9.9438,
#  10.033,
#  10.0455,
#  9.9916,
#  9.9482,
#  10.0623,
#  9.9429,
#  9.9973,
#  10.0515,
#  10.0111,
#  9.9832,
#  9.8096,
#  10.0596,
#  9.8704,
#  9.9503,
#  9.8301,
#  9.8477,
#  9.9347,
#  9.9562,
#  9.7845,
#  9.9413,
#  9.9507,
#  9.9636,
#  9.9244,
#  9.9894,
#  9.9973,
#  9.9419,
#  9.9438,
#  9.9693,
#  9.9438,
#  9.9718,
#  9.9598,
#  9.899,
#  9.9458,
#  9.8533,
#  9.7755,
#  10.0529,
#  10.0691,
#  9.7465,
#  9.8594,
#  10.0601,
#  9.7494,
#  9.9266,
#  9.9448,
#  9.9545,
#  9.9813,
#  10.0705,
#  9.9216,
#  10.06,
#  9.9486,
#  9.8445,
#  9.7209,
#  9.8135,
#  9.9247,
#  9.8171,
#  9.9192,
#  9.845,
#  9.8862,
#  10.0604,
#  9.9459,
#  9.8493,
#  10.051,
#  10.0337,
#  9.9435,
#  9.9495,
#  10.0188,
#  9.9329,
#  10.0149,
#  10.0586,
#  10.064,
#  10.064,
#  10.0603,
#  10.0513,
#  9.5903,
#  9.7602,
#  9.8205,
#  9.4167,
#  9.7553,
#  9.5903,
#  9.6012,
#  9.59,
#  9.5848,
#  9.5931,
#  9.5857,
#  9.6031,
#  9.8211,
#  9.6611,
#  9.5472,
#  9.4454,
#  9.6609,
#  9.4409,
#  9.6588,
#  9.6615,
#  9.4427,
#  9.8347,
#  9.6791,
#  9.6038,
#  9.5843,
#  9.8059,
#  9.6535,
#  9.7618,
#  9.5642,
#  9.3445,
#  9.7106,
#  9.4406,
#  9.6644,
#  9.735,
#  9.5756,
#  9.5065,
#  9.662,
#  9.5033,
#  9.5927,
#  9.6565,
#  9.6243,
#  9.6039,
#  9.5935,
#  9.7611,
#  9.7236,
#  9.6846,
#  9.6227,
#  9.6477,
#  9.8049,
#  9.815,
#  9.5935,
#  9.3999,
#  9.6066,
#  9.5933,
#  9.8243,
#  9.458,
#  9.6467,
#  9.5902,
#  9.6062,
#  9.5156,
#  9.488,
#  9.488,
#  9.5556,
#  9.814,
#  9.6579,
#  9.445,
#  9.5942,
#  9.5267,
#  9.4583,
#  9.4416,
#  9.4289,
#  9.5062,
#  9.6722,
#  9.6847,
#  9.6451,
#  9.4461,
#  9.6966,
#  9.5411,
#  9.5268,
#  9.8427,
#  9.5022,
#  9.6605,
#  9.6616,
#  9.6528,
#  9.604,
#  9.4479,
#  9.6334,
#  9.6114,
#  10.0099,
#  9.9431,
#  9.9486,
#  9.9979,
#  9.9923,
#  9.9648,
#  9.964,
#  9.9459,
#  9.9569,
#  10.0086,
#  9.9978,
#  9.9448,
#  10.0529,
#  9.9981,
#  9.9978,
#  9.9978,
#  9.9688,
#  10.0042,
#  10.0056,
#  9.9975,
#  10.0013,
#  10.0614,
#  9.9904,
#  10.0094,
#  10.0492,
#  10.0266,
#  10.0039,
#  10.016,
#  10.0011,
#  10.0151,
#  10.006,
#  10.006,
#  9.9348,
#  9.9963,
#  9.9431,
#  10.0077,
#  10.006,
#  9.9431,
#  10.0572,
#  9.9951,
#  9.9486,
#  10.0011,
#  9.997,
#  9.9586,
#  9.9989,
#  9.9996,
#  9.9952,
#  9.9762,
#  9.9874,
#  9.9954,
#  10.0076,
#  10.0056,
#  9.9681,
#  10.0479,
#  9.9977,
#  9.9402,
#  9.9865,
#  10.016,
#  10.0177,
#  9.984,
#  9.9401,
#  9.9955,
#  9.9994,
#  10.0444,
#  10.0283,
#  10.0605,
#  9.9978,
#  10.0056,
#  9.9477,
#  9.9948,
#  9.9847,
#  9.999,
#  10.0011,
#  9.9915,
#  9.9855,
#  9.997,
#  9.9467,
#  10.0608,
#  9.9988,
#  10.0058,
#  9.9948,
#  9.9955,
#  9.9952,
#  9.9542,
#  10.0136,
#  9.9469,
#  10.0013,
#  10.0015,
#  9.9956,
#  10.0431,
#  10.0248,
#  9.7263,
#  9.9227,
#  9.7257,
#  9.79,
#  9.8218,
#  9.8767,
#  9.9387,
#  9.6991,
#  9.8946,
#  9.6513,
#  9.7915,
#  9.6379,
#  9.887,
#  9.9017,
#  9.891,
#  9.6502,
#  10.0472,
#  10.0183,
#  9.9799,
#  9.8572,
#  9.8491,
#  10.1162,
#  9.8576,
#  9.7474,
#  9.9054,
#  9.7754,
#  9.8987,
#  9.9787,
#  9.846,
#  10.0897,
#  10.0638,
#  10.1051,
#  10.1179,
#  9.8572,
#  9.8298,
#  9.7546,
#  9.9112,
#  9.9215,
#  10.0065,
#  9.765,
#  9.9103,
#  9.9623,
#  10.0535,
#  9.6818,
#  9.6781,
#  10.0506,
#  9.8013,
#  9.8254,
#  9.7921,
#  9.9035,
#  9.6502,
#  9.7939,
#  9.7244,
#  9.7739,
#  9.9391,
#  9.883,
#  9.7202,
#  9.7472,
#  9.5666,
#  9.9709,
#  9.8529,
#  9.9058,
#  10.1221,
#  9.7445,
#  9.9832,
#  9.9034,
#  9.7263,
#  9.8381,
#  10.0292,
#  9.8625,
#  9.8981,
#  9.8953,
#  9.6977,
#  9.6953,
#  9.7079,
#  9.4823,
#  9.7337,
#  9.7399,
#  9.6796,
#  9.6968,
#  9.6962,
#  9.6974,
#  9.7482,
#  9.732,
#  9.7011,
#  9.7004,
#  9.6998,
#  9.6978,
#  9.7059,
#  9.7212,
#  9.7093,
#  9.7258,
#  9.7182,
#  9.7033,
#  9.6956,
#  9.6999,
#  9.6934,
#  9.7374,
#  9.7256,
#  9.7281,
#  9.7134,
#  9.7442,
#  9.7145,
#  9.7141,
#  9.7375,
#  9.7371,
#  9.6951,
#  9.7431,
#  9.7408,
#  9.7064,
#  9.6974,
#  9.7375,
#  9.7163,
#  9.7044,
#  9.4187,
#  9.4205,
#  9.4157,
#  9.4191,
#  9.4156,
#  9.4092,
#  9.4207,
#  9.4473,
#  9.4242,
#  9.4248,
#  9.4279,
#  9.4388,
#  9.4372,
#  9.4701,
#  9.4191,
#  9.4187,
#  9.4262,
#  9.4172,
#  9.4393,
#  9.4207,
#  9.4359,
#  9.4338,
#  9.4205,
#  9.4387,
#  9.4204,
#  9.4177,
#  9.4281,
#  9.43,
#  9.4298,
#  9.4279,
#  9.4588,
#  9.4344,
#  9.4413,
#  9.4092,
#  9.4325,
#  9.4208,
#  9.4191,
#  9.4337,
#  9.4306,
#  9.4199,
#  9.4097,
#  9.4196,
#  9.4313,
#  9.4485,
#  9.4256,
#  9.4331,
#  9.4198,
#  9.4057,
#  9.4096,
#  9.4311,
#  9.4368,
#  9.4324,
#  9.4283,
#  9.4196,
#  9.4249,
#  9.432,
#  9.4409,
#  9.4354,
#  9.4353,
#  9.4176,
#  9.4268,
#  9.4199,
#  9.4061,
#  9.4391,
#  9.4157,
#  9.4413,
#  9.4157,
#  9.4532,
#  9.4204,
#  9.4159,
#  9.4157,
#  9.4348,
#  9.4131,
#  9.4153,
#  9.4107,
#  9.4444,
#  9.4198,
#  9.4657,
#  9.4238,
#  9.4506,
#  9.4445,
#  9.4278,
#  9.4381,
#  9.428,
#  9.4156,
#  9.4365,
#  9.4311,
#  9.4165,
#  9.3922,
#  9.4172,
#  9.427,
#  10.2146,
#  10.2126,
#  10.2011,
#  10.2188,
#  10.213,
#  10.2072,
#  10.2557,
#  10.2547,
#  10.2489,
#  10.2669,
#  10.2495,
#  10.2489,
#  10.2335,
#  10.2342,
#  10.2011,
#  10.2335,
#  10.234,
#  10.2335,
#  10.2126,
#  10.2499,
#  10.2126,
#  10.271,
#  10.2346,
#  10.1893,
#  10.2594,
#  10.1898,
#  10.1885,
#  10.2514,
#  10.2419,
#  10.2515,
#  10.2116,
#  10.2598,
#  10.2125,
#  10.2483,
#  10.2335,
#  10.2058,
#  10.2618,
#  10.1921,
#  9.285,
#  9.1982,
#  9.1997,
#  9.3506,
#  9.3617,
#  9.1381,
#  9.2913,
#  9.2913,
#  9.2981,
#  9.2785,
#  9.2785,
#  9.2859,
#  9.3285,
#  9.3389,
#  9.365,
#  9.2604,
#  9.0908,
#  9.1012,
#  9.2041,
#  9.3048,
#  9.2793,
#  9.2912,
#  9.2041,
#  9.3647,
#  9.2255,
#  9.2326,
#  9.2889,
#  9.1715,
#  9.3031,
#  9.1069,
#  9.2469,
#  9.2858,
#  9.2447,
#  9.3104,
#  9.1838,
#  9.1659,
#  9.3281,
#  9.2781,
#  9.3313,
#  9.3076,
#  9.1487,
#  9.3565,
#  9.3637,
#  9.2558,
#  9.1412,
#  9.1871,
#  9.2486,
#  9.3542,
#  9.241,
#  9.1659,
#  9.2044,
#  9.2169,
#  9.2845,
#  9.2847,
#  9.1979,
#  9.2913,
#  9.2231,
#  9.3596,
#  9.3034,
#  9.3698,
#  9.325,
#  9.2939,
#  9.2813,
#  9.24,
#  9.2856,
#  9.2075,
#  9.2542,
#  9.1053,
#  9.275,
#  9.3081,
#  9.3209,
#  9.2376,
#  9.3064,
#  9.2939,
#  9.2298,
#  9.2853,
#  9.1871,
#  9.3192,
#  9.3177,
#  9.2653,
#  9.3417,
#  9.3146,
#  9.2487,
#  9.2436,
#  9.2392,
#  9.3565,
#  9.1994,
#  9.3814,
#  9.2845,
#  9.2192,
#  9.3211,
#  9.3022,
#  9.1896,
#  9.2039,
#  9.3052,
#  9.2842,
#  9.2011,
#  9.1596,
#  9.2341,
#  9.2094,
#  9.3216,
#  9.2461,
#  9.1812,
#  9.3504,
#  9.2302,
#  9.2913,
#  9.2853,
#  9.1852,
#  9.2878,
#  9.3143,
#  9.1792,
#  9.3133,
#  9.3057,
#  9.2486,
#  9.2893,
#  9.3371,
#  9.3058,
#  9.2604,
#  9.2035,
#  9.3033,
#  9.2059,
#  9.3044,
#  9.2591,
#  9.375,
#  9.3107,
#  9.1991,
#  9.2387,
#  9.2468,
#  9.2043,
#  9.2851,
#  9.353,
#  9.2092,
#  9.3832,
#  9.1677,
#  9.2866,
#  9.2037,
#  9.1344,
#  9.2809,
#  9.293,
#  9.1997,
#  9.3648,
#  9.2833,
#  9.2595,
#  9.2999,
#  9.1115,
#  9.2508,
#  9.3511,
#  9.1947,
#  9.3061,
#  9.2885,
#  9.1333,
#  9.2033,
#  9.3011,
#  9.2855,
#  9.2865,
#  9.2176,
#  9.2369,
#  9.2827,
#  9.2369,
#  ...]

# %%
data = df.copy()

# %%
data["Distance"] = newdis

# %%
data.head(3)
# Out:
#    fsa_id                name  \
# 0      22          Anchor Inn
# 1      36  Ark Bar Restaurant
# 2      74           Black Boy
#
#                                              address  postcode  easting  \
# 0        Upper Street, Stratford St Mary, COLCHESTER   CO7 6LW   604749
# 1  Ark Bar And Restaurant, Cattawade Street, Bran...  CO11 1RH   610194
# 2  The Lady Elizabeth, 7 Market Hill, SUDBURY, Su...  CO10 2EA   587334
#
#    northing   latitude  longitude local_authority  Distance
# 0    234404  51.970379   0.979340         Babergh   10.1453
# 1    233329  51.958698   1.057832         Babergh   10.2054
# 2    241316  52.038595   0.729915         Babergh    9.9319

# %%
top_5_pubs = data.sort_values(by='Distance').head(5)
top_5_pubs
# Out:
#        fsa_id                                         name  \
# 44632  515685                         Ness F C Social Club
# 46400  539271                                Am Fuaran Bar
# 44633  515760                          Stornoway Golf Club
# 44630  515662                                 Masonic Hall
# 44627  515616  Lewis & Harris Rangers Sports & Social Club
#
#                                                  address  postcode  easting  \
# 44632    Ness F.C. Social Club, Machair, Fivepenny, Ness   HS2 0XB   152853
# 46400                              Altandhu, Achiltibuie  IV26 2YR   198435
# 44633  Stornoway Golf Club, Castle Grounds, Stornoway...   HS2 0XP   141939
# 44630  Lodge Fortrose Masonic Hall, 57 Kenneth Street...   HS1 2DS   142360
# 44627         19 Inaclete Road, Stornoway, Isle Of Lewis   HS1 2RB   142759
#
#        northing   latitude  longitude     local_authority  Distance
# 44632    963481  58.489238  -6.242497  Na h-Eileanan Siar    1.3158
# 46400    912602  58.056551  -5.417909            Highland    1.6176
# 44633    933664  58.215919  -6.395793  Na h-Eileanan Siar    1.6290
# 44630    933050  58.210666  -6.387969  Na h-Eileanan Siar    1.6301
# 44627    932567  58.206565  -6.380664  Na h-Eileanan Siar    1.6304

# %% [markdown]
# ### To check if my location is at the land

# %%
from geopy.point import Point
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut
import requests

# Create a function to check if a point is on land
def is_on_land(lat, lon):
    try:
        # Create a geopy Point object for the given lat/lon
        point = Point(lat, lon)
        
        # Use Nominatim geocoder to reverse geocode the point and get the location name
        geolocator = Nominatim(user_agent="my_app")
        location = geolocator.reverse(f"{lat}, {lon}")
        
        # Use the location name to query the OpenStreetMap Nominatim API and get the place type
        url = f"https://nominatim.openstreetmap.org/search?q={location}&format=json&limit=1"
        response = requests.get(url).json()
        place_type = response[0]['type']
        
        # Return True if the place type is land
        return place_type == "land"
    
    except GeocoderTimedOut:
        # If geocoding fails, return False
        return False

# Test the function with a sample point
lat, lon = lat, long
is_land = is_on_land(lat, lon)
print(is_land)
# Out:
# False

# %%
import folium

# %%
m = folium.Map(location=[lat, long], zoom_start=13)
folium.Marker(location=[lat, long], icon = folium.Icon(icon='star', color='red'), popup='Your Location').add_to(m)

for i, row in top_5_pubs.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=f"<strong>{row['name']}</strong><br>{row['postcode']}<br>{row['local_authority']}<br>{row['Distance']} kelometers away",
        icon=folium.Icon(icon='beer', prefix='fa', color='green')
    ).add_to(m)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_f3b6c965530840e0909fc6356cda42b9%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f3b6c965530840e0909fc6356cda42b9%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f3b6c965530840e0909fc6356cda42b9%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_f3b6c965530840e0909fc6356cda42b9%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B59.6589%2C%20-5.63978%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ### Now want to see the total pubs in one local authority

# %%
data = data[data["local_authority"] == "County Durham"]
len(data)
# Out:
# 680

# %%
m = folium.Map(location=[data.latitude.mean(), data.longitude.mean()], zoom_start=13)
folium.Marker(location=[data.latitude.mean(), data.longitude.mean()], icon = folium.Icon(icon='star', color='red'), popup='Your Location', size = 155).add_to(m)

for i, row in data.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=f"<strong>{row['name']}</strong><br>{row['postcode']}<br>{row['local_authority']}<br>{row['Distance']} kelometers away",
        icon=folium.Icon(icon='beer', prefix='fa', color='green')
    ).add_to(m)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_5275ca84516d460a9be3f19d9eac12ff%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_5275ca84516d460a9be3f19d9eac12ff%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_5275ca84516d460a9be3f19d9eac12ff%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_5275ca84516d460a9be3f19d9eac12ff%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B54.74921242794117%2C%20-1.6357072323529411%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
df.to_csv("Cleaned_data.csv")
